# %% [markdown]
# Assignment-2 #part (b)

# %% [markdown]
# Working with the 2010 Q1 dataset break apart the performance data to a training and validation set where the training set is everything before 2015 and the validation set is everything after

# %%
import pandas as pd
from sklearn import datasets
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
performance_df=pd.read_csv("C:/Users/krish/Desktop/Preety/Performance_2010Q1.txt" , sep="|")
# Out:
# C:\Users\krish\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#print(performance_df)

# %% [markdown]
# In order to know the number of columns in the dataset

# %%
performance_df.shape
# Out:
# (999999, 31)

# %%
Columns = {0: "loan_id", 1: "DATE", 15: "forclosure_date"}
col_names = [Columns.get(idx, "%d"% idx) for idx, _ in enumerate(range(31))]
performance_df = pd.read_csv("C:/Users/krish/Desktop/Preety/Performance_2010Q1.txt",header=None,names=col_names,sep="|")
# Out:
# C:\Users\krish\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
split = performance_df['DATE'].map(lambda x: int(x[-4:])<2015)

# %%
train = performance_df[split]
test = performance_df[~split]

# %% [markdown]
# Display the training set which is everything before 2015

# %%
train
# Out:
#              loan_id        DATE                         2      3          4  \
# 0       100010079393  02/01/2010    WELLS FARGO BANK, N.A.  4.875        NaN
# 1       100010079393  03/01/2010                       NaN  4.875        NaN
# 2       100010079393  04/01/2010                       NaN  4.875        NaN
# 3       100010079393  05/01/2010                       NaN  4.875        NaN
# 4       100010079393  06/01/2010                       NaN  4.875        NaN
# 5       100010079393  07/01/2010                       NaN  4.875        NaN
# 6       100010079393  08/01/2010                       NaN  4.875  281525.61
# 7       100010079393  09/01/2010                       NaN  4.875  281166.36
# 8       100010079393  10/01/2010                       NaN  4.875  280805.65
# 9       100010079393  11/01/2010                       NaN  4.875  280443.47
# 10      100010079393  12/01/2010                       NaN  4.875  280443.47
# ...

# %% [markdown]
# Displays the test set which is everything not before 2015

# %%
test
# Out:
#              loan_id        DATE      2      3          4    5    6      7  \
# 72      100013622306  01/01/2015    NaN  4.750   64120.85   60  120  119.0
# 73      100013622306  02/01/2015    NaN  4.750   63697.94   61  119  118.0
# 74      100013622306  03/01/2015    NaN  4.750   63273.36   62  118  117.0
# 75      100013622306  04/01/2015    NaN  4.750   62847.10   63  117  116.0
# 76      100013622306  05/01/2015    NaN  4.750   62419.15   64  116  115.0
# 77      100013622306  06/01/2015    NaN  4.750   61989.51   65  115  114.0
# 78      100013622306  07/01/2015    NaN  4.750   61558.17   66  114  113.0
# 79      100013622306  08/01/2015    NaN  4.750   61125.12   67  113  112.0
# 80      100013622306  09/01/2015    NaN  4.750   60690.35   68  112  111.0
# 81      100013622306  10/01/2015    NaN  4.750   60253.86   69  111  110.0
# 82      100013622306  11/01/2015    NaN  4.750   59815.64   70  110  109.0
# ...
